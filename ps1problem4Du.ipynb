# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import norm

# %% [markdown]
# # Problem 4 Readability of QQ plots

# %% [markdown]
# ### (a)
#
# QQ Plot for sample size n = 15:

# %%
n = 15
X = np.random.standard_normal(n)
X = np.sort(X)

index = np.array([i for i in range(1,n+1)])
Z = norm.ppf(index/(n+1))

plt.plot([-4,4],[-4,4],c="grey")
plt.scatter(Z,X)
plt.show()

# %% [markdown]
# ### (b)
#
# QQ Plot for sample size n = 50:

# %%
n = 50
X = np.random.standard_normal(n)
X = np.sort(X)

index = np.array([i for i in range(1,n+1)])
Z = norm.ppf(index/(n+1))

plt.plot([-4,4],[-4,4],c="grey")
plt.scatter(Z,X)
plt.show()

# %% [markdown]
# QQ Plot for sample size n = 100

# %%
n = 100
X = np.random.standard_normal(n)
X = np.sort(X)

index = np.array([i for i in range(1,n+1)])
Z = norm.ppf(index/(n+1))

plt.plot([-4,4],[-4,4],c="grey")
plt.scatter(Z,X)

plt.show()

# %% [markdown]
# QQ Plot for sample size n = 1000

# %%
n = 1000
X = np.random.standard_normal(n)
X = np.sort(X)

index = np.array([i for i in range(1,n+1)])
Z = norm.ppf(index/(n+1))

plt.plot([-4,4],[-4,4],c="grey")
plt.scatter(Z,X)
plt.show()

# %% [markdown]
# ### (c)
#
# From the observations above, a criticle sample size could be n = 100 so that the normal-quantile plot does not deviate substanially from linearity.
